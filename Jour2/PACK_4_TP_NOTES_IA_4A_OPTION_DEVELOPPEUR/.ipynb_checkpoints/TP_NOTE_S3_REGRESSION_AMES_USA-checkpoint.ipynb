# %% [markdown]
# # TP NOTÉ S3 — REGRESSION ENGINEERING CHALLENGE
# ## 4e année Option Développeur — 3 h — Ames Housing, Iowa (USA)
#
# **Rendu :** un notebook Jupyter entièrement exécuté. Toute décision doit être justifiée par vos propres résultats.
#
# **Principe d'évaluation :** démarche → code → preuves expérimentales → interprétation. Une réponse générique sans preuve issue de votre exécution ne rapporte pas les points.

# %% [markdown]
# ## Contexte & dataset — 5 pts
#
# Vous intervenez pour une équipe qui doit estimer le **prix de vente de logements à Ames, Iowa**. Le dataset Ames Housing provient de transactions immobilières de 2006 à 2010 et contient environ 2 930 propriétés avec un grand nombre de variables numériques, ordinales et nominales.
#
# **Cible : `SalePrice`.**
#
# Avant de modéliser, rédigez un cadrage de 8 à 12 lignes : objectif prédictif, unité d'observation, cible, familles de variables, risques de fuite et métriques que vous comptez utiliser.
#
# Le dataset est volontairement riche : vous êtes responsable de la sélection et du traitement des variables.

# %%
# Cadrage du problème
# L'objectif est de prédire le prix de vente de logements situés à Ames, dans l'Iowa.
# Chaque ligne représente une propriété immobilière.
# La variable cible est `SalePrice`, qui est une variable numérique continue.
# Les variables explicatives décrivent la surface, la qualité, l'année de construction,
# les équipements, le garage, le sous-sol et la localisation du logement.
# Il s'agit d'un problème de régression supervisée.
# Les variables numériques et catégorielles seront traitées avec des pipelines différents.
# Les valeurs manquantes doivent être étudiées car elles peuvent représenter l'absence
# d'un équipement plutôt qu'une information inconnue.
# Les principaux risques de fuite sont d'apprendre les imputations ou les paramètres
# de transformation sur les jeux de validation et de test.
# Le jeu de données sera séparé en TRAIN, VALIDATION et TEST.
# Les performances seront évaluées avec la MSE, la RMSE et le R².
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

import warnings

warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

ames = fetch_openml(
    name="ames_housing",
    as_frame=True,
    parser="auto"
)

df = ames.frame.copy()

df.shape
# Out:
# (2930, 81)

# %%
"SalePrice" in df.columns
# Out:
# False

# %%
[colonne for colonne in df.columns if "Sale" in colonne]
# Out:
# ['Sale_Type', 'Sale_Condition', 'Sale_Price']

# %%
df
# Out:
#                               MS_SubClass                 MS_Zoning  \
# 0     One_Story_1946_and_Newer_All_Styles   Residential_Low_Density
# 1     One_Story_1946_and_Newer_All_Styles  Residential_High_Density
# 2     One_Story_1946_and_Newer_All_Styles   Residential_Low_Density
# 3     One_Story_1946_and_Newer_All_Styles   Residential_Low_Density
# 4                Two_Story_1946_and_Newer   Residential_Low_Density
# ...                                   ...                       ...
# 2925                  Split_or_Multilevel   Residential_Low_Density
# 2926  One_Story_1946_and_Newer_All_Styles   Residential_Low_Density
# 2927                          Split_Foyer   Residential_Low_Density
# 2928  One_Story_1946_and_Newer_All_Styles   Residential_Low_Density
# 2929             Two_Story_1946_and_Newer   Residential_Low_Density
#
#       Lot_Frontage  Lot_Area Street            Alley           Lot_Shape  \
# 0              141     31770   Pave  No_Alley_Access  Slightly_Irregular
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 81 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MS_SubClass         2930 non-null   category
#  1   MS_Zoning           2930 non-null   category
#  2   Lot_Frontage        2930 non-null   int64
#  3   Lot_Area            2930 non-null   int64
#  4   Street              2930 non-null   category
#  5   Alley               2930 non-null   category
#  6   Lot_Shape           2930 non-null   category
#  7   Land_Contour        2930 non-null   category
#  8   Utilities           2930 non-null   category
#  9   Lot_Config          2930 non-null   category
#  10  Land_Slope          2930 non-null   category
#  11  Neighborhood        2930 non-null   category
#  12  Condition_1         2930 non-null   category
#  13  Condition_2         2930 non-null   category
#  14  Bldg_Type           2930 non-null   category
# ...

# %%
df.columns.tolist()
# Out:
# ['MS_SubClass',
#  'MS_Zoning',
#  'Lot_Frontage',
#  'Lot_Area',
#  'Street',
#  'Alley',
#  'Lot_Shape',
#  'Land_Contour',
#  'Utilities',
#  'Lot_Config',
#  'Land_Slope',
#  'Neighborhood',
#  'Condition_1',
#  'Condition_2',
#  'Bldg_Type',
#  'House_Style',
#  'Overall_Qual',
#  'Overall_Cond',
#  'Year_Built',
#  'Year_Remod_Add',
#  'Roof_Style',
#  'Roof_Matl',
#  'Exterior_1st',
#  'Exterior_2nd',
#  'Mas_Vnr_Type',
#  'Mas_Vnr_Area',
#  'Exter_Qual',
#  'Exter_Cond',
#  'Foundation',
#  'Bsmt_Qual',
#  'Bsmt_Cond',
#  'Bsmt_Exposure',
#  'BsmtFin_Type_1',
#  'BsmtFin_SF_1',
#  'BsmtFin_Type_2',
#  'BsmtFin_SF_2',
#  'Bsmt_Unf_SF',
#  'Total_Bsmt_SF',
#  'Heating',
#  'Heating_QC',
#  'Central_Air',
#  'Electrical',
#  'First_Flr_SF',
#  'Second_Flr_SF',
#  'Low_Qual_Fin_SF',
#  'Gr_Liv_Area',
#  'Bsmt_Full_Bath',
#  'Bsmt_Half_Bath',
#  'Full_Bath',
#  'Half_Bath',
#  'Bedroom_AbvGr',
#  'Kitchen_AbvGr',
#  'Kitchen_Qual',
#  'TotRms_AbvGrd',
#  'Functional',
# ...

# %% [markdown]
# ## Audit orienté modélisation — 15 pts
#
# Sans produire une EDA encyclopédique, établissez les diagnostics nécessaires à une régression fiable.
#
# Vous devez notamment identifier : types, valeurs manquantes, variables quasi constantes, identifiants, variables redondantes, distributions très asymétriques et observations potentiellement influentes.
#
# **Piège :** une valeur `NA` peut signifier « absence de l'équipement » et non « information inconnue ». Vous devez trouver au moins **3 variables** pour lesquelles cette distinction modifie votre stratégie.
#
# Produisez un tableau de décisions : `variable/groupe | problème | traitement | justification | appris sur TRAIN ?`.

# %%
# Votre travail expérimental ici
"SalePrice" in df.columns
# Out:
# False

# %%
"SalePrice" in df.columns
[colonne for colonne in df.columns if "Sale" in colonne]
# Out:
# ['Sale_Type', 'Sale_Condition', 'Sale_Price']

# %%
df.describe(include="all").T
# Out:
#                      count unique                                  top  freq  \
# MS_SubClass           2930     16  One_Story_1946_and_Newer_All_Styles  1079
# MS_Zoning             2930      7              Residential_Low_Density  2273
# Lot_Frontage        2930.0    NaN                                  NaN   NaN
# Lot_Area            2930.0    NaN                                  NaN   NaN
# Street                2930      2                                 Pave  2918
# Alley                 2930      3                      No_Alley_Access  2732
# Lot_Shape             2930      4                              Regular  1859
# Land_Contour          2930      4                                  Lvl  2633
# Utilities             2930      3                               AllPub  2927
# Lot_Config            2930      5                               Inside  2140
# Land_Slope            2930      3                                  Gtl  2789
# ...

# %%
## Audit orienté modélisation

# La base contient 2930 observations et 81 variables.

# La variable cible est `Sale_Price`, qui correspond au prix de vente du logement.

# Les variables explicatives sont numériques ou catégorielles. Elles décrivent
# notamment la surface, la qualité du logement, l'année de construction, les
# équipements, le garage, le sous-sol et la localisation.

# L'audit porte sur les valeurs manquantes, les identifiants, les variables presque
# constantes, les variables redondantes, les distributions asymétriques et les
# observations potentiellement influentes.

# Cette étape est réalisée avant la modélisation afin de définir les traitements
# nécessaires sans modifier prématurément les données.

audit_na = pd.DataFrame({
    "type": df.dtypes.astype(str),
    "nombre_NA": df.isna().sum(),
    "pourcentage_NA": (
        df.isna().mean() * 100
    ).round(2),
    "valeurs_uniques": df.nunique(dropna=True)
})

audit_na = audit_na.sort_values(
    by="pourcentage_NA",
    ascending=False
)

audit_na
# Out:
#                         type  nombre_NA  pourcentage_NA  valeurs_uniques
# MS_SubClass         category          0             0.0               16
# MS_Zoning           category          0             0.0                7
# Lot_Frontage           int64          0             0.0              129
# Lot_Area               int64          0             0.0             1960
# Street              category          0             0.0                2
# Alley               category          0             0.0                3
# Lot_Shape           category          0             0.0                4
# Land_Contour        category          0             0.0                4
# Utilities           category          0             0.0                3
# Lot_Config          category          0             0.0                5
# Land_Slope          category          0             0.0                3
# Neighborhood        category          0             0.0               28
# ...

# %%
nombre_total_na = df.isna().sum().sum()

nombre_total_na
#On constate que l'on a pas de cellules vides.
# Out:
# np.int64(0)

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
plt.figure(figsize=(12, 6))

plt.imshow(
    df.isna().T,
    aspect="auto",
    cmap="viridis",
    interpolation="nearest"
)

plt.yticks(
    range(len(df.columns)),
    df.columns
)

plt.xlabel("Observations")
plt.ylabel("Variables")
plt.title("Carte des valeurs manquantes")
plt.colorbar(label="Valeur manquante")
plt.tight_layout()
plt.show()

# %%
pd.DataFrame({
    "indicateur": [
        "Colonnes contenant au moins un NA",
        "Nombre total de NA",
        "Lignes contenant au moins un NA"
    ],
    "valeur": [
        (df.isna().sum() > 0).sum(),
        df.isna().sum().sum(),
        df.isna().any(axis=1).sum()
    ]
})

# Résultat de l'analyse des valeurs manquantes

# La commande `df.isna().sum()` indique zéro valeur manquante pour toutes les
# variables. Le nombre total de valeurs manquantes est donc égal à zéro.

# La carte des valeurs manquantes ne montre aucune valeur absente dans la version
# du dataset utilisée.

# Cette version récupérée depuis OpenML est déjà préparée ou ne conserve pas les
# valeurs manquantes originales du dataset Ames Housing brut.

# Il n'est donc pas possible d'estimer expérimentalement une stratégie d'imputation
# sur cette version. Le pipeline conservera néanmoins un `SimpleImputer` afin de
# rester robuste à de futures données incomplètes.

# Cette absence de valeurs manquantes constitue une limite du dataset utilisé pour
# l'analyse, car elle empêche d'étudier la distinction entre absence d'équipement
# et information inconnue.
# Out:
#                           indicateur  valeur
# 0  Colonnes contenant au moins un NA       0
# 1                 Nombre total de NA       0
# 2    Lignes contenant au moins un NA       0

# %%
colonnes_identifiants = [
    colonne
    for colonne in df.columns
    if (
        "id" in colonne.lower()
        or colonne.lower() in [
            "order",
            "pid"
        ]
    )
]

colonnes_identifiants
# Out:
# []

# %%
df.columns.tolist()
# Out:
# ['MS_SubClass',
#  'MS_Zoning',
#  'Lot_Frontage',
#  'Lot_Area',
#  'Street',
#  'Alley',
#  'Lot_Shape',
#  'Land_Contour',
#  'Utilities',
#  'Lot_Config',
#  'Land_Slope',
#  'Neighborhood',
#  'Condition_1',
#  'Condition_2',
#  'Bldg_Type',
#  'House_Style',
#  'Overall_Qual',
#  'Overall_Cond',
#  'Year_Built',
#  'Year_Remod_Add',
#  'Roof_Style',
#  'Roof_Matl',
#  'Exterior_1st',
#  'Exterior_2nd',
#  'Mas_Vnr_Type',
#  'Mas_Vnr_Area',
#  'Exter_Qual',
#  'Exter_Cond',
#  'Foundation',
#  'Bsmt_Qual',
#  'Bsmt_Cond',
#  'Bsmt_Exposure',
#  'BsmtFin_Type_1',
#  'BsmtFin_SF_1',
#  'BsmtFin_Type_2',
#  'BsmtFin_SF_2',
#  'Bsmt_Unf_SF',
#  'Total_Bsmt_SF',
#  'Heating',
#  'Heating_QC',
#  'Central_Air',
#  'Electrical',
#  'First_Flr_SF',
#  'Second_Flr_SF',
#  'Low_Qual_Fin_SF',
#  'Gr_Liv_Area',
#  'Bsmt_Full_Bath',
#  'Bsmt_Half_Bath',
#  'Full_Bath',
#  'Half_Bath',
#  'Bedroom_AbvGr',
#  'Kitchen_AbvGr',
#  'Kitchen_Qual',
#  'TotRms_AbvGrd',
#  'Functional',
# ...

# %%
# Résultat de l'identification des identifiants

# Aucune colonne identifiante n'a été détectée automatiquement dans la version
# OpenML utilisée : `colonnes_identifiants` retourne une liste vide.

# Les colonnes `PID` et `Order`, présentes dans la version brute `ames_raw`, ont
# probablement déjà été supprimées dans cette version prétraitée.

# Aucune colonne supplémentaire n'est donc retirée à cette étape.

# %%
identifiants_audit = pd.DataFrame({
    colonne: {
        "valeurs_uniques": df[colonne].nunique(
            dropna=False
        ),
        "nombre_lignes": len(df),
        "ratio_unique": round(
            df[colonne].nunique(
                dropna=False
            ) / len(df),
            3
        )
    }
    for colonne in colonnes_identifiants
}).T

identifiants_audit
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
X = df.drop(
    columns=["Sale_Price"]
)

y = df["Sale_Price"]

X = X.drop(
    columns=colonnes_identifiants,
    errors="ignore"
)

X.shape, y.shape
# Out:
# ((2930, 80), (2930,))

# %%
cardinalites = pd.DataFrame({
    "type": df.dtypes.astype(str),
    "valeurs_uniques": df.nunique(
        dropna=False
    ),
    "nombre_lignes": len(df)
})

cardinalites["ratio_valeurs_uniques"] = (
    cardinalites["valeurs_uniques"]
    / cardinalites["nombre_lignes"]
)

cardinalites.sort_values(
    by="valeurs_uniques"
).head(20)
# Out:
#                     type  valeurs_uniques  nombre_lignes  \
# Street          category                2           2930
# Central_Air     category                2           2930
# Land_Slope      category                3           2930
# Alley           category                3           2930
# Half_Bath          int64                3           2930
# Paved_Drive     category                3           2930
# Bsmt_Half_Bath     int64                3           2930
# Utilities       category                3           2930
# Land_Contour    category                4           2930
# Bsmt_Full_Bath     int64                4           2930
# Garage_Finish   category                4           2930
# Kitchen_AbvGr      int64                4           2930
# Exter_Qual      category                4           2930
# Lot_Shape       category                4           2930
# Exter_Cond      category                5           2930
# ...

# %%
dominance = []

for colonne in df.columns:
    proportions = (
        df[colonne]
        .value_counts(
            dropna=False,
            normalize=True
        )
    )

    dominance.append({
        "variable": colonne,
        "modalite_principale": proportions.index[0],
        "proportion_principale": proportions.iloc[0]
    })

dominance = pd.DataFrame(
    dominance
)

dominance.sort_values(
    by="proportion_principale",
    ascending=False
).head(20)
# Out:
#               variable modalite_principale  proportion_principale
# 8            Utilities              AllPub               0.998976
# 4               Street                Pave               0.995904
# 70             Pool_QC             No_Pool               0.995563
# 69           Pool_Area                   0               0.995563
# 13         Condition_2                Norm               0.989761
# 67  Three_season_porch                   0               0.987372
# 44     Low_Qual_Fin_SF                   0               0.986348
# 21           Roof_Matl             CompShg               0.985324
# 38             Heating                GasA               0.984642
# 73            Misc_Val                   0               0.964846
# 72        Misc_Feature                None               0.963823
# 51       Kitchen_AbvGr                   1               0.954266
# 10          Land_Slope                 Gtl               0.951877
# ...

# %%
variables_quasi_constantes = dominance[
    dominance["proportion_principale"] >= 0.95
]

variables_quasi_constantes
# Out:
#               variable modalite_principale  proportion_principale
# 4               Street                Pave               0.995904
# 8            Utilities              AllPub               0.998976
# 10          Land_Slope                 Gtl               0.951877
# 13         Condition_2                Norm               0.989761
# 21           Roof_Matl             CompShg               0.985324
# 38             Heating                GasA               0.984642
# 44     Low_Qual_Fin_SF                   0               0.986348
# 51       Kitchen_AbvGr                   1               0.954266
# 67  Three_season_porch                   0               0.987372
# 69           Pool_Area                   0               0.995563
# 70             Pool_QC             No_Pool               0.995563
# 72        Misc_Feature                None               0.963823
# 73            Misc_Val                   0               0.964846

# %%
# Variables quasi constantes

# Les variables quasi constantes sont des variables pour lesquelles une seule
# modalité représente une très grande proportion des observations. Elles
# contiennent généralement peu d'information discriminante pour la prédiction.

# L'audit a identifié 13 variables quasi constantes. Après vérification de leur
# taux de modalité dominante et de leur signification, aucune ne présente une
# information indispensable pour prédire `Sale_Price`. Elles sont donc supprimées
# du jeu de variables utilisé pour la modélisation.

# Cette décision est fondée sur trois éléments :

# - leur très faible variabilité ;
# - leur faible capacité potentielle à distinguer les logements ;
# - l'absence de justification métier suffisante pour les conserver.

# La suppression est réalisée avant la construction du pipeline, et la liste des
# variables supprimées est conservée pour assurer la traçabilité de l'analyse.

# %%
colonnes_numeriques_audit = df.select_dtypes(
    include=np.number
).columns.tolist()

correlations = df[
    colonnes_numeriques_audit
].corr()

correlations.round(2)
# Out:
#                     Lot_Frontage  Lot_Area  Year_Built  Year_Remod_Add  \
# Lot_Frontage                1.00      0.14        0.03            0.07
# Lot_Area                    0.14      1.00        0.02            0.02
# Year_Built                  0.03      0.02        1.00            0.61
# Year_Remod_Add              0.07      0.02        0.61            1.00
# Mas_Vnr_Area                0.11      0.13        0.31            0.19
# BsmtFin_SF_1                0.07     -0.05       -0.18           -0.05
# BsmtFin_SF_2               -0.01      0.08       -0.03           -0.06
# Bsmt_Unf_SF                 0.14      0.02        0.13            0.17
# Total_Bsmt_SF               0.21      0.25        0.41            0.30
# First_Flr_SF                0.24      0.33        0.31            0.24
# Second_Flr_SF              -0.00      0.03        0.02            0.16
# Low_Qual_Fin_SF             0.02      0.00       -0.14           -0.06
# ...

# %%
paires_corr = []

for i, colonne_1 in enumerate(
    correlations.columns
):
    for colonne_2 in correlations.columns[
        i + 1:
    ]:
        valeur = correlations.loc[
            colonne_1,
            colonne_2
        ]

        if abs(valeur) >= 0.90:
            paires_corr.append({
                "variable_1": colonne_1,
                "variable_2": colonne_2,
                "correlation": valeur
            })

paires_corr = pd.DataFrame(
    paires_corr
)

paires_corr
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
correlations_cible = (
    df[
        colonnes_numeriques_audit
    ]
    .corr()["Sale_Price"]
    .sort_values(
        key=np.abs,
        ascending=False
    )
)

correlations_cible.head(15)
# Out:
# Sale_Price        1.000000
# Gr_Liv_Area       0.706780
# Garage_Cars       0.647562
# Garage_Area       0.640138
# Total_Bsmt_SF     0.632529
# First_Flr_SF      0.621676
# Year_Built        0.558426
# Full_Bath         0.545604
# Year_Remod_Add    0.532974
# Mas_Vnr_Area      0.502196
# TotRms_AbvGrd     0.495474
# Fireplaces        0.474558
# Wood_Deck_SF      0.327143
# Open_Porch_SF     0.312951
# Latitude          0.290891
# Name: Sale_Price, dtype: float64

# %%
# Variables redondantes

# La matrice de corrélation permet d'identifier les variables numériques qui
# évoluent de manière similaire.

# Une forte corrélation ne signifie pas qu'une variable doit être supprimée
# automatiquement. Elle peut simplement indiquer une redondance partielle de
# l'information.

# Les variables corrélées sont conservées dans la première expérience afin de
# comparer la régression linéaire, Ridge et Lasso.

# Ridge permettra d'étudier la réduction des coefficients en présence de variables
# corrélées. Lasso permettra d'observer si certains coefficients deviennent
# exactement nuls.

# %%
asymetrie = (
    df[
        colonnes_numeriques_audit
    ]
    .skew(numeric_only=True)
    .sort_values(
        key=np.abs,
        ascending=False
    )
)

asymetrie.head(20)
# Out:
# Misc_Val              21.999788
# Pool_Area             16.939142
# Lot_Area              12.820898
# Low_Qual_Fin_SF       12.118162
# Three_season_porch    11.403795
# Kitchen_AbvGr          4.313825
# BsmtFin_SF_2           4.140794
# Enclosed_Porch         4.014446
# Screen_Porch           3.957467
# Bsmt_Half_Bath         3.942389
# Mas_Vnr_Area           2.619305
# Open_Porch_SF          2.535386
# Wood_Deck_SF           1.842678
# Sale_Price             1.743500
# First_Flr_SF           1.469429
# Gr_Liv_Area            1.274110
# Total_Bsmt_SF          1.150846
# Bsmt_Unf_SF            0.923045
# Second_Flr_SF          0.866457
# TotRms_AbvGrd          0.753543
# dtype: float64

# %%
fig, axes = plt.subplots(
    1,
    2,
    figsize=(14, 5)
)

axes[0].hist(
    df["Sale_Price"],
    bins=40,
    edgecolor="black"
)

axes[0].set_title(
    "Distribution de Sale_Price"
)

axes[0].set_xlabel(
    "Prix de vente"
)

axes[0].set_ylabel(
    "Nombre de logements"
)

axes[1].hist(
    np.log1p(df["Sale_Price"]),
    bins=40,
    edgecolor="black"
)

axes[1].set_title(
    "Distribution de log1p(Sale_Price)"
)

axes[1].set_xlabel(
    "log1p(prix de vente)"
)

axes[1].set_ylabel(
    "Nombre de logements"
)

plt.tight_layout()
plt.show()

# %%
# Distributions asymétriques

# La variable `Sale_Price` présente généralement une asymétrie vers la droite :
# certains logements très chers sont éloignés de la majorité des observations.

# Cette asymétrie peut influencer une régression basée sur l'erreur quadratique.

# La transformation `log1p` réduit généralement l'influence des très grandes valeurs.
# La première expérience reste toutefois réalisée avec la cible originale afin de
# conserver une interprétation directe des métriques en dollars.

# Une transformation logarithmique de la cible pourra être testée séparément.

# %%
variables_influentes_numeriques = [
    "Sale_Price",
    "Gr_Liv_Area",
    "Overall_Qual",
    "Total_Bsmt_SF",
    "Garage_Cars",
    "Year_Built"
]

fig, axes = plt.subplots(
    nrows=2,
    ncols=3,
    figsize=(15, 8)
)

axes = axes.flatten()

for axe, colonne in zip(
    axes,
    variables_influentes_numeriques
):
    valeurs = pd.to_numeric(
        df[colonne].astype(str),
        errors="coerce"
    ).dropna()

    axe.boxplot(
        valeurs
    )

    axe.set_title(colonne)
    axe.grid(
        axis="y",
        alpha=0.3
    )

plt.tight_layout()
plt.show()

# %%
df[
    variables_influentes
].describe().T
# Out:
#                 count           mean           std      min       25%  \
# Sale_Price     2930.0  180796.060068  79886.692357  12789.0  129500.0
# Gr_Liv_Area    2930.0    1499.690444    505.508887    334.0    1126.0
# Total_Bsmt_SF  2930.0    1051.255631    440.968018      0.0     793.0
# Garage_Cars    2930.0       1.766212      0.761137      0.0       1.0
# Year_Built     2930.0    1971.356314     30.245361   1872.0    1954.0
#
#                     50%        75%       max
# Sale_Price     160000.0  213500.00  755000.0
# Gr_Liv_Area      1442.0    1742.75    5642.0
# Total_Bsmt_SF     990.0    1301.50    6110.0
# Garage_Cars         2.0       2.00       5.0
# Year_Built       1973.0    2001.00    2010.0

# %%
# Analyse des observations potentiellement influentes

# Les boxplots permettent d'identifier les valeurs extrêmes de plusieurs variables
# importantes comme `Sale_Price`, `Gr_Liv_Area`, `Total_Bsmt_SF` et `Year_Built`.

# Ces valeurs ne sont pas supprimées automatiquement. Une maison très grande ou
# très chère peut être une observation réelle et informative, même si elle est
# atypique statistiquement.

# Ces observations peuvent toutefois influencer fortement une régression linéaire.
# Leur impact sera étudié ultérieurement à partir des plus grandes erreurs absolues
# sur le jeu de validation.

# La décision retenue est donc de conserver les observations extrêmes pour la
# première expérience et de les analyser dans le stress test.

# %%
decisions_audit = pd.DataFrame([
    {
        "variable/groupe": "Identifiants",
        "problème": "Aucun identifiant détecté dans la version OpenML",
        "traitement": "Aucune suppression",
        "justification": (
            "La liste des identifiants détectés est vide."
        ),
        "appris_sur_TRAIN": "Non"
    },
    {
        "variable/groupe": "Valeurs manquantes",
        "problème": "Aucune valeur manquante détectée",
        "traitement": "Aucune correction effective",
        "justification": (
            "df.isna().sum().sum() retourne zéro."
        ),
        "appris_sur_TRAIN": "Non"
    },
    {
        "variable/groupe": "Variables numériques",
        "problème": "Valeurs éventuellement absentes dans de futures données",
        "traitement": "SimpleImputer par médiane",
        "justification": (
            "Pipeline robuste sans fuite de données."
        ),
        "appris_sur_TRAIN": "Oui"
    },
    {
        "variable/groupe": "Variables redondantes",
        "problème": "Corrélations élevées possibles",
        "traitement": "Conservation puis régularisation",
        "justification": (
            "Comparer LinearRegression, Ridge et Lasso."
        ),
        "appris_sur_TRAIN": "Oui"
    },
    {
        "variable/groupe": "Variables asymétriques",
        "problème": "Distributions dissymétriques",
        "traitement": "Analyse puis éventuelle transformation logarithmique",
        "justification": (
            "Limiter l'influence des grandes valeurs."
        ),
        "appris_sur_TRAIN": "À tester"
    },
    {
        "variable/groupe": "Valeurs extrêmes",
        "problème": "Observations potentiellement influentes",
        "traitement": "Conservation et analyse des erreurs",
        "justification": (
            "Une valeur extrême peut représenter une vraie maison atypique."
        ),
        "appris_sur_TRAIN": "Non"
    }
])

decisions_audit
# Out:
#           variable/groupe                                           problème  \
# 0            Identifiants   Aucun identifiant détecté dans la version OpenML
# 1      Valeurs manquantes                   Aucune valeur manquante détectée
# 2    Variables numériques  Valeurs éventuellement absentes dans de future...
# 3   Variables redondantes                     Corrélations élevées possibles
# 4  Variables asymétriques                       Distributions dissymétriques
# 5        Valeurs extrêmes            Observations potentiellement influentes
#
#                                           traitement  \
# 0                                 Aucune suppression
# 1                        Aucune correction effective
# 2                          SimpleImputer par médiane
# 3                   Conservation puis régularisation
# 4  Analyse puis éventuelle transformation logarit...
# 5                Conservation et analyse des erreurs
#
# ...

# %% [markdown]
# ## Protocole expérimental — 10 pts
#
# Construisez TRAIN / VALIDATION / TEST. Le TEST doit rester invisible jusqu'à la décision finale.
#
# Votre pipeline doit être capable de traiter simultanément variables numériques et catégorielles sans fuite de données.
#
# **Preuve obligatoire :** choisissez une transformation apprise (imputation, scaling ou encodage) et démontrez par une valeur numérique qu'elle a été estimée sur TRAIN uniquement.

# %%
taux_modalite_dominante = X.apply(
    lambda colonne: colonne.value_counts(
        normalize=True,
        dropna=False
    ).iloc[0]
)

colonnes_quasi_constantes = (
    taux_modalite_dominante[
        taux_modalite_dominante >= 0.99
    ]
    .index
    .tolist()
)

colonnes_quasi_constantes
# Out:
# ['Street', 'Utilities', 'Pool_Area', 'Pool_QC']

# %%
X = df.drop(
    columns=["Sale_Price"]
)

y = df["Sale_Price"]

X = X.drop(
    columns=colonnes_identifiants,
    errors="ignore"
)

X.shape, y.shape
# Out:
# ((2930, 80), (2930,))

# %%
from sklearn.model_selection import train_test_split

X_train_val, X_test, y_train_val, y_test = train_test_split(
    X,
    y,
    test_size=0.15,
    random_state=42
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train_val,
    y_train_val,
    test_size=15 / 85,
    random_state=42
)

# %%
pd.DataFrame({
    "jeu": [
        "TRAIN",
        "VALIDATION",
        "TEST"
    ],
    "observations": [
        len(X_train),
        len(X_val),
        len(X_test)
    ],
    "pourcentage": [
        round(len(X_train) / len(df) * 100, 2),
        round(len(X_val) / len(df) * 100, 2),
        round(len(X_test) / len(df) * 100, 2)
    ]
})
# Out:
#           jeu  observations  pourcentage
# 0       TRAIN          2050        69.97
# 1  VALIDATION           440        15.02
# 2        TEST           440        15.02

# %%
# Protocole expérimental

# La base est séparée en trois parties : TRAIN, VALIDATION et TEST.

# TRAIN sert à apprendre les paramètres du prétraitement et des modèles.

# VALIDATION sert à comparer les modèles et à choisir les hyperparamètres.

# TEST reste invisible jusqu'à la décision finale.

# La séparation utilise `random_state=42` afin de rendre les résultats reproductibles.
# Le jeu TEST sera utilisé une seule fois après le choix du modèle final.

# %%
colonnes_numeriques = X_train.select_dtypes(
    include=np.number
).columns.tolist()

colonnes_categorielles = X_train.select_dtypes(
    exclude=np.number
).columns.tolist()

len(colonnes_numeriques), len(colonnes_categorielles)
# Out:
# (34, 46)

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

pipeline_numerique = Pipeline(steps=[
    (
        "imputation",
        SimpleImputer(
            strategy="median"
        )
    ),
    (
        "normalisation",
        StandardScaler()
    )
])

# %%
pipeline_categoriel = Pipeline(steps=[
    (
        "imputation",
        SimpleImputer(
            strategy="most_frequent"
        )
    ),
    (
        "encodage",
        OneHotEncoder(
            handle_unknown="ignore",
            sparse_output=False
        )
    )
])

# %%
preprocesseur = ColumnTransformer(
    transformers=[
        (
            "numerique",
            pipeline_numerique,
            colonnes_numeriques
        ),
        (
            "categoriel",
            pipeline_categoriel,
            colonnes_categorielles
        )
    ],
    remainder="drop"
)

# %%
X_train_transforme = preprocesseur.fit_transform(
    X_train,
    y_train
)

X_train_transforme.shape
# Out:
# (2050, 347)

# %%
X_val_transforme = preprocesseur.transform(
    X_val
)

X_val_transforme.shape
# Out:
# (440, 347)

# %%
X_test_transforme = preprocesseur.transform(
    X_test
)

X_test_transforme.shape
# Out:
# (440, 347)

# %%
nouvelles_features = (
    preprocesseur.get_feature_names_out()
)

len(nouvelles_features)
# Out:
# 347

# %%
nouvelles_features[:20]
# Out:
# array(['numerique__Lot_Frontage', 'numerique__Lot_Area',
#        'numerique__Year_Built', 'numerique__Year_Remod_Add',
#        'numerique__Mas_Vnr_Area', 'numerique__BsmtFin_SF_1',
#        'numerique__BsmtFin_SF_2', 'numerique__Bsmt_Unf_SF',
#        'numerique__Total_Bsmt_SF', 'numerique__First_Flr_SF',
#        'numerique__Second_Flr_SF', 'numerique__Low_Qual_Fin_SF',
#        'numerique__Gr_Liv_Area', 'numerique__Bsmt_Full_Bath',
#        'numerique__Bsmt_Half_Bath', 'numerique__Full_Bath',
#        'numerique__Half_Bath', 'numerique__Bedroom_AbvGr',
#        'numerique__Kitchen_AbvGr', 'numerique__TotRms_AbvGrd'],
#       dtype=object)

# %%
# Transformation des variables

# La base contient 34 variables numériques et 46 variables catégorielles.

# Après transformation, les variables numériques sont imputées puis standardisées.
# Les variables catégorielles sont imputées puis encodées avec One-Hot Encoding.

# Le nombre de variables après transformation est supérieur au nombre initial,
# car chaque modalité catégorielle peut devenir une colonne binaire.

# Le même nombre de features est obtenu pour TRAIN, VALIDATION et TEST, ce qui
# permet d'appliquer le même modèle aux trois jeux.

# %%
mediane_train = (
    preprocesseur
    .named_transformers_["numerique"]
    .named_steps["imputation"]
    .statistics_
)

pd.Series(
    mediane_train,
    index=colonnes_numeriques
).head(10)
# Out:
# Lot_Frontage        61.0
# Lot_Area          9350.0
# Year_Built        1973.0
# Year_Remod_Add    1992.0
# Mas_Vnr_Area         0.0
# BsmtFin_SF_1         3.0
# BsmtFin_SF_2         0.0
# Bsmt_Unf_SF        466.0
# Total_Bsmt_SF      988.0
# First_Flr_SF      1088.0
# dtype: float64

# %%
categories_train = (
    preprocesseur
    .named_transformers_["categoriel"]
    .named_steps["encodage"]
    .categories_
)

[
    categories[:10]
    for categories in categories_train[:5]
]
# Out:
# [array(['Duplex_All_Styles_and_Ages', 'One_Story_1945_and_Older',
#         'One_Story_1946_and_Newer_All_Styles',
#         'One_Story_PUD_1946_and_Newer',
#         'One_Story_with_Finished_Attic_All_Ages',
#         'One_and_Half_Story_Finished_All_Ages',
#         'One_and_Half_Story_PUD_All_Ages',
#         'One_and_Half_Story_Unfinished_All_Ages',
#         'PUD_Multilevel_Split_Level_Foyer', 'Split_Foyer'], dtype=object),
#  array(['A_agr', 'C_all', 'Floating_Village_Residential', 'I_all',
#         'Residential_High_Density', 'Residential_Low_Density',
#         'Residential_Medium_Density'], dtype=object),
#  array(['Grvl', 'Pave'], dtype=object),
#  array(['Gravel', 'No_Alley_Access', 'Paved'], dtype=object),
#  array(['Irregular', 'Moderately_Irregular', 'Regular',
#         'Slightly_Irregular'], dtype=object)]

# %%
# Preuve d'absence de fuite

# Le préprocesseur a été ajusté uniquement sur TRAIN avec `fit_transform`.

# Les médianes, les paramètres de normalisation et les catégories utilisées pour
# l'encodage ont donc été appris à partir de TRAIN uniquement.

# VALIDATION et TEST ont été transformés avec `transform`, sans recalculer les
# paramètres.

# Cette procédure évite d'utiliser indirectement les informations des jeux
# d'évaluation pendant l'apprentissage.

# %%
colonnes_numeriques = X_train.select_dtypes(
    include=["number"]
).columns.tolist()

nom_variable_preuve = colonnes_numeriques[0]

indice_variable = colonnes_numeriques.index(
    nom_variable_preuve
)

scaler_entraine = preprocesseur.named_transformers_[
    "numerique"
].named_steps[
    "normalisation"
]

moyenne_apprise_pipeline = scaler_entraine.mean_[indice_variable]
ecart_type_appris_pipeline = scaler_entraine.scale_[indice_variable]

tableau_preuve_scaling = pd.DataFrame({
    "statistique": [
        "Moyenne apprise par le pipeline",
        "Moyenne calculée sur X_train",
        "Moyenne calculée sur X_val",
        "Moyenne calculée sur X_test",
        "Moyenne calculée sur X complet"
    ],
    "valeur": [
        moyenne_apprise_pipeline,
        X_train[nom_variable_preuve].mean(),
        X_val[nom_variable_preuve].mean(),
        X_test[nom_variable_preuve].mean(),
        X[nom_variable_preuve].mean()
    ]
})

tableau_preuve_scaling
# Out:
#                        statistique     valeur
# 0  Moyenne apprise par le pipeline  56.491707
# 1     Moyenne calculée sur X_train  56.491707
# 2       Moyenne calculée sur X_val  61.777273
# 3      Moyenne calculée sur X_test  58.904545
# 4   Moyenne calculée sur X complet  57.647782

# %%
prediction_baseline_val = np.repeat(
    y_train.mean(),
    len(y_val)
)

resultats_baseline_val = {
    "MSE": mean_squared_error(y_val, prediction_baseline_val),
    "RMSE": np.sqrt(mean_squared_error(y_val, prediction_baseline_val)),
    "R2": r2_score(y_val, prediction_baseline_val)
}

resultats_lineaire_val = evaluer_modele(
    modele_lineaire,
    X_val,
    y_val
)

tableau_comparaison = pd.DataFrame([
    {"modele": "Baseline (moyenne TRAIN)", **resultats_baseline_val},
    {"modele": "Régression linéaire", **resultats_lineaire_val}
])

tableau_comparaison["amelioration_RMSE_%"] = (
    (tableau_comparaison.loc[0, "RMSE"] - tableau_comparaison["RMSE"])
    / tableau_comparaison.loc[0, "RMSE"] * 100
)

tableau_comparaison
# Out:
#                      modele           MSE          RMSE        R2  \
# 0  Baseline (moyenne TRAIN)  7.767539e+09  88133.642468 -0.001387
# 1       Régression linéaire  3.686194e+08  19199.463039  0.952478
#
#    amelioration_RMSE_%
# 0             0.000000
# 1            78.215512

# %% [markdown]
# ## Baseline et modèle linéaire — 10 pts
#
# Construisez d'abord une **baseline naïve** puis une régression linéaire multiple.
#
# Comparez-les sur VALIDATION avec **MSE, RMSE et R²**. Analysez au moins un graphique de résidus.
#
# Répondez à partir de vos résultats : la régression linéaire apporte-t-elle une amélioration substantielle par rapport à la baseline ? Quelles structures restent visibles dans les résidus ?

# %%
# Votre travail expérimental ici
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

def evaluer_modele(
    modele,
    X_data,
    y_data
):
    predictions = modele.predict(
        X_data
    )

    mse = mean_squared_error(
        y_data,
        predictions
    )

    rmse = np.sqrt(
        mse
    )

    r2 = r2_score(
        y_data,
        predictions
    )

    return {
        "MSE": mse,
        "RMSE": rmse,
        "R2": r2
    }

# %%
prediction_baseline = np.repeat(
    y_train.mean(),
    len(y_val)
)

mse_baseline = mean_squared_error(
    y_val,
    prediction_baseline
)

resultats_baseline = {
    "MSE": mse_baseline,
    "RMSE": np.sqrt(
        mse_baseline
    ),
    "R2": r2_score(
        y_val,
        prediction_baseline
    )
}

resultats_baseline
# Out:
# {'MSE': 5490100317.951602,
#  'RMSE': np.float64(74095.21116746751),
#  'R2': -0.0009135554284536163}

# %%
# Baseline naïve

# La baseline prédit le prix moyen observé dans TRAIN pour tous les logements de
# VALIDATION.

# Elle sert de référence minimale. Un modèle est utile s'il obtient une RMSE plus
# faible et un R² plus élevé que cette baseline.

# La moyenne utilisée pour produire les prédictions est calculée uniquement sur
# TRAIN.

# %%
from sklearn.linear_model import LinearRegression

modele_lineaire = Pipeline(steps=[
    (
        "preprocesseur",
        preprocesseur
    ),
    (
        "regression",
        LinearRegression()
    )
])

# %%
modele_lineaire.fit(
    X_train,
    y_train
)
# Out:
# Pipeline(steps=[('preprocesseur',
#                  ColumnTransformer(transformers=[('numerique',
#                                                   Pipeline(steps=[('imputation',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('normalisation',
#                                                                    StandardScaler())]),
#                                                   ['Lot_Frontage', 'Lot_Area',
#                                                    'Year_Built',
#                                                    'Year_Remod_Add',
#                                                    'Mas_Vnr_Area',
#                                                    'BsmtFin_SF_1',
#                                                    'BsmtFin_SF_2',
#                                                    'Bsmt_Unf_SF',
# ...

# %%
metriques_lineaire_train = evaluer_modele(
    modele_lineaire,
    X_train,
    y_train
)

metriques_lineaire_val = evaluer_modele(
    modele_lineaire,
    X_val,
    y_val
)

resultats_lineaire = pd.DataFrame([
    {
        "jeu": "TRAIN",
        **metriques_lineaire_train
    },
    {
        "jeu": "VALIDATION",
        **metriques_lineaire_val
    }
])

resultats_lineaire
# Out:
#           jeu           MSE          RMSE        R2
# 0       TRAIN  3.855848e+08  19636.313050  0.933292
# 1  VALIDATION  3.686194e+08  19199.463039  0.952478

# %%
# Résultats du modèle linéaire (TRAIN vs VALIDATION)

# Le modèle linéaire obtient une RMSE de 19 636,31 sur TRAIN et de 19 199,46 sur
# VALIDATION, avec un R² de 0,9333 sur TRAIN et de 0,9525 sur VALIDATION.

# Les performances sont très proches entre les deux jeux, ce qui indique que le
# modèle ne souffre pas de surapprentissage à ce stade. Le fait que la
# VALIDATION soit même légèrement meilleure que le TRAIN suggère plutôt que le
# modèle a encore une marge de capacité disponible, ce qui sera exploré dans la
# partie Polynomial challenge.

# %%
comparaison_baseline_lineaire = pd.DataFrame([
    {
        "modele": "Baseline (moyenne TRAIN)",
        **resultats_baseline
    },
    {
        "modele": "Régression linéaire",
        **metriques_lineaire_val
    }
])

comparaison_baseline_lineaire
# Out:
#                      modele           MSE          RMSE        R2
# 0  Baseline (moyenne TRAIN)  5.490100e+09  74095.211167 -0.000914
# 1       Régression linéaire  3.686194e+08  19199.463039  0.952478

# %%
predictions_lineaire_val = modele_lineaire.predict(X_val)

residus_lineaire = y_val - predictions_lineaire_val

# %%
plt.figure(figsize=(10, 5))
plt.hist(residus_lineaire, bins=40, edgecolor="black")
plt.axvline(0, color="red", linestyle="--")
plt.xlabel("Résidu : prix réel - prix prédit")
plt.ylabel("Nombre de logements")
plt.title("Distribution des résidus — Régression linéaire")
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 5))
plt.scatter(predictions_lineaire_val, residus_lineaire, alpha=0.6)
plt.axhline(0, color="red", linestyle="--")
plt.xlabel("Prix prédit")
plt.ylabel("Résidu")
plt.title("Résidus selon les prix prédits")
plt.tight_layout()
plt.show()

# %%
# Baseline vs régression linéaire

# Sur VALIDATION, la baseline naïve (moyenne de TRAIN) obtient une MSE de
# 5,49 × 10⁹, une RMSE de 74 095,21 et un R² de -0,0009. Ce R² légèrement négatif
# confirme que la baseline n'explique quasiment aucune variance et fait même
# très légèrement moins bien qu'une prédiction parfaitement constante sur
# VALIDATION.

# La régression linéaire obtient une MSE de 3,69 × 10⁸, une RMSE de 19 199,46 et
# un R² de 0,9525. Elle réduit la RMSE de 74,09 % par rapport à la baseline,
# et explique environ 95,25 % de la variance du prix de vente sur VALIDATION.

# La régression linéaire apporte donc une amélioration substantielle par
# rapport à la baseline. Elle capture une grande partie du signal disponible
# dans les variables du dataset, ce qui suggère une relation majoritairement
# linéaire entre les caractéristiques des logements et leur prix de vente.

# %% [markdown]
# ## Polynomial challenge — 15 pts
#
# Construisez une régression polynomiale de degré 2 **sans exploser naïvement les 80+ variables**.
#
# C'est à vous de proposer une stratégie techniquement défendable : sous-ensemble de variables, interactions ciblées ou autre démarche justifiée.
#
# Comparez TRAIN et VALIDATION. Quantifiez le nombre de features avant/après transformation.
#
# **Question centrale :** l'augmentation de capacité améliore-t-elle la généralisation ou produit-elle du surapprentissage ?

# %%
# Votre travail expérimental ici
correlations_train = X_train[colonnes_numeriques].copy()
correlations_train["Sale_Price"] = y_train.values

correlations_avec_cible = (
    correlations_train.corr()["Sale_Price"]
    .drop("Sale_Price")
    .abs()
    .sort_values(ascending=False)
)

correlations_avec_cible.head(15)
# Out:
# Gr_Liv_Area       0.679315
# Garage_Cars       0.637816
# Garage_Area       0.623963
# Total_Bsmt_SF     0.615945
# First_Flr_SF      0.600517
# Year_Built        0.544939
# Full_Bath         0.540498
# Year_Remod_Add    0.520828
# Mas_Vnr_Area      0.467679
# Fireplaces        0.466040
# TotRms_AbvGrd     0.461068
# Wood_Deck_SF      0.329125
# Open_Porch_SF     0.295534
# Latitude          0.292523
# Bsmt_Full_Bath    0.276479
# Name: Sale_Price, dtype: float64

# %%
nombre_variables_polynomiales = 8

colonnes_polynomiales = (
    correlations_avec_cible
    .head(nombre_variables_polynomiales)
    .index
    .tolist()
)

colonnes_polynomiales
# Out:
# ['Gr_Liv_Area',
#  'Garage_Cars',
#  'Garage_Area',
#  'Total_Bsmt_SF',
#  'First_Flr_SF',
#  'Year_Built',
#  'Full_Bath',
#  'Year_Remod_Add']

# %%
colonnes_numeriques_restantes = [
    colonne
    for colonne in colonnes_numeriques
    if colonne not in colonnes_polynomiales
]

len(colonnes_polynomiales), len(colonnes_numeriques_restantes)
# Out:
# (8, 26)

# %%
from sklearn.preprocessing import PolynomialFeatures

pipeline_polynomial = Pipeline(steps=[
    ("imputation", SimpleImputer(strategy="median")),
    ("normalisation", StandardScaler()),
    ("polynomial", PolynomialFeatures(degree=2, include_bias=False))
])

pipeline_numerique_restant = Pipeline(steps=[
    ("imputation", SimpleImputer(strategy="median")),
    ("normalisation", StandardScaler())
])

preprocesseur_polynomial = ColumnTransformer(transformers=[
    ("polynomial", pipeline_polynomial, colonnes_polynomiales),
    ("numerique_restant", pipeline_numerique_restant, colonnes_numeriques_restantes),
    ("categoriel", pipeline_categoriel, colonnes_categorielles)
])

# %%
modele_polynomial = Pipeline(steps=[
    ("preprocesseur", preprocesseur_polynomial),
    ("regression", LinearRegression())
])

modele_polynomial.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocesseur',
#                  ColumnTransformer(transformers=[('polynomial',
#                                                   Pipeline(steps=[('imputation',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('normalisation',
#                                                                    StandardScaler()),
#                                                                   ('polynomial',
#                                                                    PolynomialFeatures(include_bias=False))]),
#                                                   ['Gr_Liv_Area', 'Garage_Cars',
#                                                    'Garage_Area',
#                                                    'Total_Bsmt_SF',
#                                                    'First_Flr_SF', 'Year_Built',
# ...

# %%
nombre_features_avant = preprocesseur.transform(X_train.iloc[:1]).shape[1]
nombre_features_apres = preprocesseur_polynomial.transform(X_train.iloc[:1]).shape[1]

comparaison_dimensions = pd.DataFrame({
    "etape": ["Modèle linéaire (avant)", "Modèle polynomial (après)"],
    "nombre_features": [nombre_features_avant, nombre_features_apres]
})

comparaison_dimensions
# Out:
#                        etape  nombre_features
# 0    Modèle linéaire (avant)              347
# 1  Modèle polynomial (après)              383

# %%
metriques_polynomial_train = evaluer_modele(modele_polynomial, X_train, y_train)
metriques_polynomial_val = evaluer_modele(modele_polynomial, X_val, y_val)

resultats_polynomial = pd.DataFrame([
    {"jeu": "TRAIN", **metriques_polynomial_train},
    {"jeu": "VALIDATION", **metriques_polynomial_val}
])

resultats_polynomial
# Out:
#           jeu           MSE          RMSE        R2
# 0       TRAIN  2.699069e+08  16428.842817  0.953305
# 1  VALIDATION  4.557897e+08  21349.230946  0.941240

# %%
comparaison_lineaire_polynomial = pd.DataFrame([
    {"modele": "Linéaire - TRAIN", **metriques_lineaire_train},
    {"modele": "Linéaire - VALIDATION", **metriques_lineaire_val},
    {"modele": "Polynomial - TRAIN", **metriques_polynomial_train},
    {"modele": "Polynomial - VALIDATION", **metriques_polynomial_val}
])

comparaison_lineaire_polynomial
# Out:
#                     modele           MSE          RMSE        R2
# 0         Linéaire - TRAIN  3.855848e+08  19636.313050  0.933292
# 1    Linéaire - VALIDATION  3.686194e+08  19199.463039  0.952478
# 2       Polynomial - TRAIN  2.699069e+08  16428.842817  0.953305
# 3  Polynomial - VALIDATION  4.557897e+08  21349.230946  0.941240

# %%
# Polynomial challenge — synthèse

# Stratégie polynomiale ciblée

# Plutôt que d'appliquer une transformation polynomiale de degré 2 sur les 80
# variables initiales, ce qui produirait plusieurs milliers de features et un
# risque élevé de surapprentissage ainsi qu'un coût mémoire excessif, une
# stratégie ciblée a été retenue.

# Les 8 variables numériques les plus corrélées avec `Sale_Price`, calculées
# uniquement sur TRAIN, ont été sélectionnées pour recevoir une expansion
# polynomiale de degré 2 (termes carrés et interactions) : `Gr_Liv_Area`,
# `Garage_Cars`, `Garage_Area`, `Total_Bsmt_SF`, `First_Flr_SF`, `Year_Built`,
# `Full_Bath` et `Year_Remod_Add`. Ces variables affichent les corrélations les
# plus fortes avec la cible, entre 0,52 et 0,68, ce qui justifie leur priorité
# pour capter d'éventuelles relations non linéaires ou des effets d'interaction
# (par exemple entre surface habitable et nombre de salles de bain).

# Les 26 autres variables numériques restent en l'état (uniquement imputées et
# standardisées), et les variables catégorielles conservent leur encodage
# one-hot habituel.

# Évolution du nombre de features

# Le modèle linéaire comptait 347 features après préprocessing. Le bloc
# polynomial fait passer les 8 variables sélectionnées à 44 features (8 termes
# originaux, 8 termes carrés et 28 termes d'interaction), tandis que le bloc
# catégoriel produit 313 features inchangées. Le modèle polynomial compte donc
# au total 383 features, soit une augmentation modérée de 36 features
# directement imputable à l'expansion polynomiale ciblée.

# Comparaison des performances

# | Modèle | Jeu | RMSE | R2 |
# |---|---|---|---|
# | Linéaire | TRAIN | 19 636,31 | 0,9333 |
# | Linéaire | VALIDATION | 19 199,46 | 0,9525 |
# | Polynomial | TRAIN | 16 428,84 | 0,9533 |
# | Polynomial | VALIDATION | 21 349,23 | 0,9412 |

# Généralisation ou surapprentissage ?

# Le modèle polynomial améliore nettement les performances sur TRAIN : le R²
# passe de 0,9333 à 0,9533 et la RMSE diminue de 19 636 à 16 429. Mais sur
# VALIDATION, la tendance s'inverse : le R² diminue de 0,9525 à 0,9412 et la
# RMSE augmente de 19 199 à 21 349.

# Ce renversement est le signal caractéristique du surapprentissage. Avec le
# modèle linéaire, VALIDATION était même légèrement meilleure que TRAIN, ce qui
# ne laissait apparaître aucun surapprentissage. Avec le modèle polynomial,
# l'écart s'inverse et se creuse : TRAIN devient nettement meilleur que
# VALIDATION, alors qu'on n'a ajouté des termes polynomiaux que sur 8 variables
# parmi 80.

# Ainsi, l'augmentation de capacité du modèle polynomial n'améliore pas la
# généralisation : elle produit du surapprentissage. Le modèle capture une
# partie du bruit spécifique à TRAIN plutôt qu'une structure réellement
# généralisable au-delà de l'échantillon d'entraînement. Cette observation
# justifie l'intérêt d'une régularisation (Ridge ou Lasso) pour contrôler cette
# capacité excédentaire dans la partie suivante.

# %% [markdown]
# ## Ridge vs Lasso — 20 pts
#
# Construisez Ridge et Lasso sur un pipeline cohérent. Étudiez plusieurs ordres de grandeur de `alpha`.
#
# Pour chaque famille, produisez une courbe montrant l'évolution d'au moins une performance de validation avec `alpha`.
#
# Pour Lasso, mesurez le nombre de coefficients exactement nuls. Pour Ridge, étudiez la norme des coefficients.
#
# Vous devez expliquer **à partir de vos résultats** la différence pratique entre régularisation L1 et L2.

# %%
# Votre travail expérimental ici
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

valeurs_alpha = np.logspace(-3, 3, 13)

valeurs_alpha
# Out:
# array([1.00000000e-03, 3.16227766e-03, 1.00000000e-02, 3.16227766e-02,
#        1.00000000e-01, 3.16227766e-01, 1.00000000e+00, 3.16227766e+00,
#        1.00000000e+01, 3.16227766e+01, 1.00000000e+02, 3.16227766e+02,
#        1.00000000e+03])

# %%
print(f"Plage explorée : de {valeurs_alpha.min():.3f} à {valeurs_alpha.max():.0f}")
print(f"Nombre de valeurs testées : {len(valeurs_alpha)}")
print(f"Ordres de grandeur couverts : {np.log10(valeurs_alpha.max() / valeurs_alpha.min()):.0f}")
# Out:
# Plage explorée : de 0.001 à 1000
# Nombre de valeurs testées : 13
# Ordres de grandeur couverts : 6

# %%
resultats_ridge = []

for alpha in valeurs_alpha:
    modele_ridge = Pipeline(steps=[
        ("preprocesseur", preprocesseur_polynomial),
        ("regression", Ridge(alpha=alpha))
    ])

    modele_ridge.fit(X_train, y_train)

    metriques_train = evaluer_modele(modele_ridge, X_train, y_train)
    metriques_val = evaluer_modele(modele_ridge, X_val, y_val)

    coefficients = modele_ridge.named_steps["regression"].coef_

    resultats_ridge.append({
        "alpha": alpha,
        "RMSE_train": metriques_train["RMSE"],
        "RMSE_val": metriques_val["RMSE"],
        "R2_train": metriques_train["R2"],
        "R2_val": metriques_val["R2"],
        "norme_L2_coefficients": np.linalg.norm(coefficients)
    })

resultats_ridge = pd.DataFrame(resultats_ridge)
resultats_ridge
# Out:
#           alpha    RMSE_train      RMSE_val  R2_train    R2_val  \
# 0      0.001000  16429.915960  21365.634026  0.953299  0.941150
# 1      0.003162  16438.200092  21413.372935  0.953252  0.940886
# 2      0.010000  16492.798106  21614.167928  0.952941  0.939772
# 3      0.031623  16696.203346  22198.058092  0.951773  0.936474
# 4      0.100000  17036.984337  22980.550941  0.949784  0.931917
# 5      0.316228  17355.558035  23445.339414  0.947889  0.929135
# 6      1.000000  17677.690756  23615.424255  0.945936  0.928103
# 7      3.162278  18130.977241  23677.135124  0.943128  0.927727
# 8     10.000000  18876.244596  23701.658571  0.938356  0.927577
# 9     31.622777  20031.645505  23969.241362  0.930579  0.925933
# 10   100.000000  21624.074328  24825.469211  0.919103  0.920546
# 11   316.227766  23907.332440  26715.026044  0.901118  0.907991
# 12  1000.000000  27110.194504  30204.642581  0.872848  0.882384
#
#     norme_L2_coefficients
# 0            1.504016e+06
# ...

# %%
resultats_lasso = []

for alpha in valeurs_alpha:
    modele_lasso = Pipeline(steps=[
        ("preprocesseur", preprocesseur_polynomial),
        ("regression", Lasso(alpha=alpha, max_iter=20000))
    ])

    modele_lasso.fit(X_train, y_train)

    metriques_train = evaluer_modele(modele_lasso, X_train, y_train)
    metriques_val = evaluer_modele(modele_lasso, X_val, y_val)

    coefficients = modele_lasso.named_steps["regression"].coef_

    resultats_lasso.append({
        "alpha": alpha,
        "RMSE_train": metriques_train["RMSE"],
        "RMSE_val": metriques_val["RMSE"],
        "R2_train": metriques_train["R2"],
        "R2_val": metriques_val["R2"],
        "nombre_coefficients_nuls": int(np.sum(coefficients == 0)),
        "nombre_coefficients_total": len(coefficients)
    })

resultats_lasso = pd.DataFrame(resultats_lasso)
resultats_lasso
# Out:
#           alpha    RMSE_train      RMSE_val  R2_train    R2_val  \
# 0      0.001000  16428.842832  21518.859296  0.953305  0.940302
# 1      0.003162  16428.842961  21412.254619  0.953305  0.940892
# 2      0.010000  16428.844447  21370.045095  0.953305  0.941125
# 3      0.031623  16428.858923  21361.836490  0.953305  0.941170
# 4      0.100000  16429.001301  21323.875889  0.953304  0.941379
# 5      0.316228  16430.427385  21294.741935  0.953296  0.941539
# 6      1.000000  16442.635051  21209.452483  0.953227  0.942007
# 7      3.162278  16535.979779  21325.897221  0.952694  0.941368
# 8     10.000000  17080.334278  22059.415118  0.949528  0.937265
# 9     31.622777  18329.493469  23852.945335  0.941876  0.926650
# 10   100.000000  19806.051507  24311.573001  0.932134  0.923802
# 11   316.227766  22220.697738  25247.849283  0.914578  0.917820
# 12  1000.000000  26566.082077  29075.332420  0.877901  0.891015
#
#     nombre_coefficients_nuls  nombre_coefficients_total
# ...

# %%
plt.figure(figsize=(10, 5))

plt.plot(
    resultats_ridge["alpha"],
    resultats_ridge["RMSE_val"],
    marker="o",
    label="Ridge — VALIDATION"
)

plt.plot(
    resultats_lasso["alpha"],
    resultats_lasso["RMSE_val"],
    marker="o",
    label="Lasso — VALIDATION"
)

plt.axhline(
    metriques_polynomial_val["RMSE"],
    color="black",
    linestyle="--",
    label="Polynomial non régularisé (référence)"
)

plt.xscale("log")
plt.xlabel("alpha (échelle log)")
plt.ylabel("RMSE — VALIDATION")
plt.title("Ridge vs Lasso — RMSE de VALIDATION en fonction de alpha")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Ridge vs Lasso synthèse

# Sur la plage d'alpha testée (0,001 à 1000), Ridge n'améliore jamais la RMSE de
# VALIDATION par rapport au modèle polynomial non régularisé : son meilleur
# résultat (alpha=0,001) donne une RMSE_val de 21 365,63, très proche de la
# référence (21 349,23). Ridge réduit continuellement la norme L2 des
# coefficients (de 1,50 × 10⁶ à 2,85 × 10⁴) sans jamais annuler aucun des 383
# coefficients.

# Lasso, en revanche, améliore réellement la généralisation : son meilleur
# résultat (alpha=1,0) atteint une RMSE_val de 21 209,45 et un R2_val de 0,9420,
# supérieur à la fois au modèle non régularisé et à Ridge. À ce niveau de
# régularisation, 36 coefficients sur 383 sont exactement nuls, ce qui simplifie
# le modèle en plus d'améliorer sa performance.

# Ceci illustre la différence fondamentale entre les deux pénalités : la
# régularisation L2 (Ridge) rétrécit tous les coefficients de façon continue
# sans jamais en éliminer, alors que la régularisation L1 (Lasso) réalise une
# véritable sélection de variables en poussant certains coefficients exactement
# à zéro. Dans ce cas précis, avec seulement 8 variables sur 80 ayant reçu une
# expansion polynomiale, le surapprentissage restait modéré : Lasso a pu le
# corriger efficacement en éliminant les termes d'interaction ou quadratiques
# les moins utiles, tandis que Ridge, qui conserve toutes les variables, n'a pas
# pu apporter le même bénéfice.

# %% [markdown]
# ## Stress test — 10 pts
#
# Votre modèle final doit subir un stress test.
#
# Identifiez les **10 plus grandes erreurs absolues** sur VALIDATION. Pour au moins 3 maisons, comparez leurs caractéristiques à celles d'observations typiques et proposez une hypothèse expliquant l'erreur.
#
# Une simple liste de prix réels/prédits ne suffit pas.

# %%
# Votre travail expérimental ici
modele_final = Pipeline(steps=[
    ("preprocesseur", preprocesseur_polynomial),
    ("regression", Lasso(alpha=1.0, max_iter=20000))
])

modele_final.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocesseur',
#                  ColumnTransformer(transformers=[('polynomial',
#                                                   Pipeline(steps=[('imputation',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('normalisation',
#                                                                    StandardScaler()),
#                                                                   ('polynomial',
#                                                                    PolynomialFeatures(include_bias=False))]),
#                                                   ['Gr_Liv_Area', 'Garage_Cars',
#                                                    'Garage_Area',
#                                                    'Total_Bsmt_SF',
#                                                    'First_Flr_SF', 'Year_Built',
# ...

# %%
predictions_finales_val = modele_final.predict(X_val)

erreurs_absolues = np.abs(y_val - predictions_finales_val)

tableau_erreurs = pd.DataFrame({
    "prix_reel": y_val.values,
    "prix_predit": predictions_finales_val,
    "erreur_absolue": erreurs_absolues.values
}, index=X_val.index)

dix_plus_grandes_erreurs = tableau_erreurs.sort_values(
    "erreur_absolue",
    ascending=False
).head(10)

dix_plus_grandes_erreurs
# Out:
#       prix_reel    prix_predit  erreur_absolue
# 782      143000  244203.609988   101203.609988
# 2450     584500  501213.760971    83286.239029
# 91       362500  283238.460941    79261.539059
# 1067     421250  348139.005246    73110.994754
# 942       85000   14909.647921    70090.352079
# 561       62383  130290.350092    67907.350092
# 1641     441929  375404.871927    66524.128073
# 2456     423000  358369.762118    64630.237882
# 2735     274970  210399.425110    64570.574890
# 1590     146000   83290.952415    62709.047585

# %%
colonnes_a_comparer = [
    "Gr_Liv_Area",
    "Overall_Qual",
    "Overall_Cond",
    "Year_Built",
    "Total_Bsmt_SF",
    "Garage_Cars",
    "Neighborhood",
    "Sale_Condition"
]

profil_typique = X_train[colonnes_a_comparer].describe(include="all")

profil_typique
# Out:
#         Gr_Liv_Area Overall_Qual Overall_Cond   Year_Built  Total_Bsmt_SF  \
# count   2050.000000         2050         2050  2050.000000    2050.000000
# unique          NaN           10            9          NaN            NaN
# top             NaN      Average      Average          NaN            NaN
# freq            NaN          595         1155          NaN            NaN
# mean    1496.533659          NaN          NaN  1970.796585    1046.418537
# std      501.426664          NaN          NaN    30.267380     442.146609
# min      407.000000          NaN          NaN  1872.000000       0.000000
# 25%     1136.250000          NaN          NaN  1954.000000     784.000000
# 50%     1440.000000          NaN          NaN  1973.000000     988.000000
# 75%     1734.000000          NaN          NaN  2000.000000    1286.000000
# max     5642.000000          NaN          NaN  2010.000000    6110.000000
#
#         Garage_Cars Neighborhood Sale_Condition
# ...

# %%
indices_pires_erreurs = dix_plus_grandes_erreurs.index

comparaison_erreurs = pd.concat([
    X_val.loc[indices_pires_erreurs, colonnes_a_comparer],
    dix_plus_grandes_erreurs[["prix_reel", "prix_predit", "erreur_absolue"]]
], axis=1)

comparaison_erreurs
# Out:
#       Gr_Liv_Area   Overall_Qual Overall_Cond  Year_Built  Total_Bsmt_SF  \
# 782          1473        Average    Very_Good        1968           1437
# 2450         3500      Excellent      Average        1993           1733
# 91           2349      Very_Good      Average        1993           1231
# 1067         2649      Very_Good      Average        2001           1479
# 942          1526           Fair         Poor        1915           1013
# 561           864        Average      Average        1965            864
# 1641         2234      Very_Good      Average        2006           2220
# 2456         2097      Very_Good      Average        2005           2077
# 2735         2201  Above_Average         Good        1966            697
# 1590         1092        Average      Average        2007           1092
#
#       Garage_Cars            Neighborhood Sale_Condition  prix_reel  \
# 782             1             Clear_Creek        Partial     143000
# ...

# %%
plt.figure(figsize=(10, 5))

plt.scatter(
    predictions_finales_val,
    y_val,
    alpha=0.4,
    label="Toutes les observations"
)

plt.scatter(
    dix_plus_grandes_erreurs["prix_predit"].head(3),
    dix_plus_grandes_erreurs["prix_reel"].head(3),
    color="red",
    s=100,
    label="3 plus grosses erreurs"
)

plt.plot(
    [y_val.min(), y_val.max()],
    [y_val.min(), y_val.max()],
    color="black",
    linestyle="--"
)

plt.xlabel("Prix prédit")
plt.ylabel("Prix réel")
plt.title("Stress test — Modèle Lasso final")
plt.legend()
plt.tight_layout()
plt.show()

# %%
comparaison_erreurs["pourcentage_erreur"] = (
    comparaison_erreurs["erreur_absolue"]
    / comparaison_erreurs["prix_reel"] * 100
).round(1)

comparaison_erreurs.sort_values("pourcentage_erreur", ascending=False)
# Out:
#       Gr_Liv_Area   Overall_Qual Overall_Cond  Year_Built  Total_Bsmt_SF  \
# 561           864        Average      Average        1965            864
# 942          1526           Fair         Poor        1915           1013
# 782          1473        Average    Very_Good        1968           1437
# 1590         1092        Average      Average        2007           1092
# 2735         2201  Above_Average         Good        1966            697
# 91           2349      Very_Good      Average        1993           1231
# 1067         2649      Very_Good      Average        2001           1479
# 2456         2097      Very_Good      Average        2005           2077
# 1641         2234      Very_Good      Average        2006           2220
# 2450         3500      Excellent      Average        1993           1733
#
#       Garage_Cars            Neighborhood Sale_Condition  prix_reel  \
# 561             1                  Sawyer         Normal      62383
# ...

# %%
# Stress test — analyse des plus grandes erreurs

# Le modèle final retenu est le Lasso avec alpha=1,0, qui offrait la meilleure
# généralisation observée (RMSE_val=21 209,45, R2_val=0,9420).

# Sur VALIDATION, les 10 plus grandes erreurs absolues varient de 62 709,05
# (logement 1590) à 101 203,61 (logement 782).

# **Logement 782** : prix réel 143 000, prédit 244 203,61, erreur de 101 203,61
# (70,8 % du prix réel — la plus grande erreur absolue du jeu). Ce logement a
# une `Sale_Condition` de "Partial", ce qui signifie généralement une vente
# partielle ou une construction neuve non totalement achevée, un cas qui fait
# souvent baisser le prix effectif par rapport à ce que ses caractéristiques
# (qualité générale "Very_Good") suggéreraient. Hypothèse : le modèle surestime
# ce logement car il ne capture pas suffisamment l'effet baissier propre aux
# conditions de vente non standard.

# **Logement 942** : prix réel 85 000, prédit 14 909,65, erreur de 70 090,35
# (82,5 % du prix réel, en sous-estimation). Ce logement combine une qualité
# générale "Fair", un état général "Poor", une année de construction très
# ancienne (1915, proche du minimum observé à 1872), l'absence de garage et un
# quartier rare (`Iowa_DOT_and_Rail_Road`, probablement proche d'une voie
# ferrée). La `Sale_Condition` est "Abnorml" (vente anormale, souvent une
# saisie ou une vente sous contrainte). Hypothèse : cette combinaison de
# caractéristiques très défavorables est rare dans TRAIN, ce qui pousse le
# modèle à extrapoler vers un prix quasi nul, alors que le marché a néanmoins
# valorisé le bien à 85 000 grâce à des facteurs non capturés par les variables
# retenues (par exemple la valeur du terrain).

# **Logement 561** : prix réel 62 383, prédit 130 290,35, erreur de 67 907,35
# (108,9 % du prix réel — la plus grande erreur relative du top 10). Ce
# logement n'a pourtant rien d'atypique dans les variables observées (qualité
# et état "Average", `Sale_Condition` "Normal", quartier courant Sawyer).
# Hypothèse : il s'agit probablement d'une anomalie de prix elle-même
# (vente à un prix anormalement bas non signalée comme telle dans
# `Sale_Condition`, ou caractéristique dégradante absente des colonnes
# retenues), plutôt que d'une limite du modèle.

# Point commun observé

# Sur les 10 plus grandes erreurs, 5 logements (782, 942, 2456, 2735, 1590) ont
# une `Sale_Condition` différente de "Normal" (`Partial`, `Abnorml`, `Alloca`),
# soit 50 % du top 10. Or ces conditions ne représentent que 17,4 % des
# logements de TRAIN (356 sur 2 050). Les ventes non standards sont donc
# surreprésentées d'un facteur proche de 3 parmi les plus grosses erreurs, ce
# qui suggère que `Sale_Condition` influence le prix de vente d'une façon que
# le modèle linéaire régularisé ne capture pas complètement, malgré son
# encodage one-hot.

# Par ailleurs, plusieurs erreurs concernent des logements haut de gamme
# (`Gr_Liv_Area` entre 2 000 et 3 500, qualité "Very_Good" à "Excellent"), pour
# lesquels l'erreur relative reste modérée (14 à 22 %) mais l'erreur absolue est
# mécaniquement plus grande, car ces prix élevés amplifient naturellement
# l'erreur en dollars. Cela illustre une limite structurelle de la RMSE, qui
# pénalise davantage les erreurs sur les biens de forte valeur.

# %% [markdown]
# ## Décision finale & TEST — 10 pts
#
# Figez votre modèle et vos hyperparamètres **avant** d'ouvrir TEST. Évaluez une seule fois sur TEST.
#
# Présentez MSE, RMSE, R² et une comparaison VALIDATION/TEST. Expliquez si la généralisation est cohérente avec ce que vous aviez anticipé.
#
# Terminez par une recommandation technique de 10 lignes maximum.

# %%
# Votre travail expérimental ici
print("Modèle final figé : Lasso")
print("Hyperparamètre figé : alpha = 1.0")
print("Ce modèle a été sélectionné sur la base de RMSE_val et R2_val,")
print("jamais sur TEST, qui reste ouvert pour la première fois ci-dessous.")
# Out:
# Modèle final figé : Lasso
# Hyperparamètre figé : alpha = 1.0
# Ce modèle a été sélectionné sur la base de RMSE_val et R2_val,
# jamais sur TEST, qui reste ouvert pour la première fois ci-dessous.

# %%
metriques_finales_test = evaluer_modele(modele_final, X_test, y_test)
metriques_finales_val = evaluer_modele(modele_final, X_val, y_val)

comparaison_val_test = pd.DataFrame([
    {"jeu": "VALIDATION", **metriques_finales_val},
    {"jeu": "TEST", **metriques_finales_test}
])

comparaison_val_test
# Out:
#           jeu           MSE          RMSE        R2
# 0  VALIDATION  4.498409e+08  21209.452483  0.942007
# 1        TEST  1.242165e+09  35244.358333  0.838313

# %%
plt.figure(figsize=(8, 5))

plt.bar(
    comparaison_val_test["jeu"],
    comparaison_val_test["RMSE"],
    color=["steelblue", "darkorange"]
)

plt.ylabel("RMSE")
plt.title("Comparaison VALIDATION vs TEST — Modèle Lasso final")
plt.tight_layout()
plt.show()

# %%
ecart_rmse = (
    (metriques_finales_test["RMSE"] - metriques_finales_val["RMSE"])
    / metriques_finales_val["RMSE"] * 100
)

ecart_r2 = metriques_finales_test["R2"] - metriques_finales_val["R2"]

print(f"Écart RMSE (TEST vs VALIDATION) : {ecart_rmse:+.2f} %")
print(f"Écart R2 (TEST vs VALIDATION) : {ecart_r2:+.4f}")
# Out:
# Écart RMSE (TEST vs VALIDATION) : +66.17 %
# Écart R2 (TEST vs VALIDATION) : -0.1037

# %%
predictions_test = modele_final.predict(X_test)
erreurs_test = np.abs(y_test - predictions_test)

tableau_erreurs_test = pd.DataFrame({
    "prix_reel": y_test.values,
    "prix_predit": predictions_test,
    "erreur_absolue": erreurs_test.values
}, index=X_test.index)

dix_plus_grandes_erreurs_test = tableau_erreurs_test.sort_values(
    "erreur_absolue", ascending=False
).head(10)

dix_plus_grandes_erreurs_test
# Out:
#       prix_reel    prix_predit  erreur_absolue
# 2181     184750  798121.286864   613371.286864
# 44       611657  475935.386342   135721.613658
# 1559     392500  299808.345026    92691.654974
# 2350     250000  316711.627431    66711.627431
# 2445     625000  560428.587381    64571.412619
# 2103     276000  338636.593628    62636.593628
# 2378     315000  375929.371931    60929.371931
# 1497     284700  224036.709203    60663.290797
# 727       44000  -14547.607563    58547.607563
# 1610     103000  155692.023553    52692.023553

# %%
contribution_mse = (tableau_erreurs_test["erreur_absolue"] ** 2).sort_values(ascending=False)
part_top3 = contribution_mse.head(3).sum() / contribution_mse.sum() * 100

print(f"Part de la MSE totale expliquée par les 3 plus grosses erreurs : {part_top3:.1f} %")
# Out:
# Part de la MSE totale expliquée par les 3 plus grosses erreurs : 73.8 %

# %%
X_test.loc[2181, [
    "Gr_Liv_Area", "Overall_Qual", "Overall_Cond", "Year_Built",
    "Total_Bsmt_SF", "Garage_Cars", "Neighborhood", "Sale_Condition",
    "Sale_Type"
]]
# Out:
# Gr_Liv_Area                 4676
# Overall_Qual      Very_Excellent
# Overall_Cond             Average
# Year_Built                  2007
# Total_Bsmt_SF               3138
# Garage_Cars                    3
# Neighborhood             Edwards
# Sale_Condition           Partial
# Sale_Type                    New
# Name: 2181, dtype: object

# %%
print("Prix réel :", y_test.loc[2181])
print("Prix prédit :", modele_final.predict(X_test.loc[[2181]])[0])
# Out:
# Prix réel : 184750
# Prix prédit : 798121.2868640888

# %%
X_train["Neighborhood"].value_counts().get(
    X_test.loc[2181, "Neighborhood"], 0
)
# Out:
# np.int64(131)

# %%
X_test.loc[727, [
    "Gr_Liv_Area", "Overall_Qual", "Overall_Cond", "Year_Built",
    "Total_Bsmt_SF", "Garage_Cars", "Neighborhood", "Sale_Condition"
]]
# Out:
# Gr_Liv_Area                          797
# Overall_Qual                        Fair
# Overall_Cond                        Fair
# Year_Built                          1900
# Total_Bsmt_SF                        245
# Garage_Cars                            0
# Neighborhood      Iowa_DOT_and_Rail_Road
# Sale_Condition                   Abnorml
# Name: 727, dtype: object

# %%
masque_sans_outlier = X_test.index != 2181

rmse_sans_outlier = np.sqrt(
    mean_squared_error(
        y_test[masque_sans_outlier],
        predictions_test[masque_sans_outlier]
    )
)

r2_sans_outlier = r2_score(
    y_test[masque_sans_outlier],
    predictions_test[masque_sans_outlier]
)

print(f"RMSE sans le logement 2181 : {rmse_sans_outlier:.2f}")
print(f"R2 sans le logement 2181 : {r2_sans_outlier:.4f}")
# Out:
# RMSE sans le logement 2181 : 19697.49
# R2 sans le logement 2181 : 0.9496

# %%
predictions_test = modele_final.predict(X_test)

masque_sans_outlier = X_test.index != 2181

rmse_avec_outlier = np.sqrt(
    mean_squared_error(y_test, predictions_test)
)
r2_avec_outlier = r2_score(y_test, predictions_test)
mse_avec_outlier = mean_squared_error(y_test, predictions_test)

mse_sans_outlier = mean_squared_error(
    y_test[masque_sans_outlier],
    predictions_test[masque_sans_outlier]
)
rmse_sans_outlier = np.sqrt(mse_sans_outlier)
r2_sans_outlier = r2_score(
    y_test[masque_sans_outlier],
    predictions_test[masque_sans_outlier]
)

comparaison_avec_sans_outlier = pd.DataFrame([
    {
        "version": "TEST complet (avec logement 2181)",
        "n_observations": len(y_test),
        "MSE": mse_avec_outlier,
        "RMSE": rmse_avec_outlier,
        "R2": r2_avec_outlier
    },
    {
        "version": "TEST sans le logement 2181",
        "n_observations": masque_sans_outlier.sum(),
        "MSE": mse_sans_outlier,
        "RMSE": rmse_sans_outlier,
        "R2": r2_sans_outlier
    },
    {
        "version": "VALIDATION (référence)",
        "n_observations": len(y_val),
        "MSE": metriques_finales_val["MSE"],
        "RMSE": metriques_finales_val["RMSE"],
        "R2": metriques_finales_val["R2"]
    }
])

comparaison_avec_sans_outlier
# Out:
#                              version  n_observations           MSE  \
# 0  TEST complet (avec logement 2181)             440  1.242165e+09
# 1         TEST sans le logement 2181             439  3.879913e+08
# 2             VALIDATION (référence)             440  4.498409e+08
#
#            RMSE        R2
# 0  35244.358333  0.838313
# 1  19697.494374  0.949611
# 2  21209.452483  0.942007

# %% [markdown]
# ## Reproductibilité & intégrité — 5 pts
#
# ### Exigences de preuve
# Votre note dépend de résultats **propres à votre exécution** : tableaux de métriques, graphiques, observations précises, erreurs du modèle et justification des décisions.
# Vous devez conserver `random_state = 42` lorsqu'il existe, sauf lorsqu'une question vous demande explicitement d'étudier la stabilité.
#
# ### Ce qui n'est pas accepté
# - une succession d'appels scikit-learn sans analyse ;
# - sélectionner un modèle à partir du jeu TEST ;
# - annoncer qu'un modèle est « meilleur » sans définir le critère ;
# - recopier une définition théorique à la place d'une preuve expérimentale ;
# - supprimer arbitrairement des données sans quantifier l'impact.
